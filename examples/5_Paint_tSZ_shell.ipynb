# %%
import matplotlib.pyplot as plt
import numpy as np
import healpy as hp
import sys, os; sys.path.append('../../')
import Baryonification as bfn
import pyccl as ccl
from astropy.io import fits

#Load cosmology object from CCL. Linear P(k) is needed since we use it for 2-halo term.
#We don't use P(k) anywhere else in this model, so it's ok to use linear P(k) throughout
cosmo = ccl.Cosmology(Omega_c = 0.3175, Omega_b = 0.049, h = 0.6711, sigma8 = 0.834, n_s = 0.9649, 
                      matter_power_spectrum='linear')

#Config params. Can change as you need. I store these as a dict and then unpack.
bpar = np.load('./default_config.npy', allow_pickle = True)[()]

#Just to make the variation in params more extreme
bpar['mu_beta'] = 1

# %%
#Some plotting configs
plt.rc('text', usetex=True)
plt.rc('font', family='serif', size=22)
plt.rcParams["axes.linewidth"]  = 2.0
plt.rcParams["xtick.major.size"]  = 10
plt.rcParams["xtick.minor.size"]  = 5
plt.rcParams["ytick.major.size"]  = 10
plt.rcParams["ytick.minor.size"]  = 5
plt.rcParams["xtick.direction"]  = "in"
plt.rcParams["ytick.direction"]  = "in"
plt.rcParams["legend.frameon"] = 'False'
plt.rcParams['figure.figsize'] = [10, 10]

# %% [markdown]
# ## Download files
#
# These are files from the [ULAGAM simulations](https://ulagam-simulations.readthedocs.io/) hosted on gdrive specifically for this example notebook

# %%
# !rm shell.fits.fz halos.npy

# !wget -O shell.fits.fz "https://drive.google.com/uc?export=download&id=1JjH5EnW4TlNF8n823K9-DnbkqczL5dj6"
# !wget -O halos.npy     "https://drive.google.com/uc?export=download&id=1JhtFwOzfHG5YWXUDYP1HFfAkq6v5YHKm"
# Out:
# --2024-08-29 14:44:17--  https://drive.google.com/uc?export=download&id=1JjH5EnW4TlNF8n823K9-DnbkqczL5dj6
# Resolving drive.google.com (drive.google.com)... 142.250.191.238, 2607:f8b0:4009:81b::200e
# Connecting to drive.google.com (drive.google.com)|142.250.191.238|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1JjH5EnW4TlNF8n823K9-DnbkqczL5dj6&export=download [following]
# --2024-08-29 14:44:17--  https://drive.usercontent.google.com/download?id=1JjH5EnW4TlNF8n823K9-DnbkqczL5dj6&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 142.250.190.97, 2607:f8b0:4009:80b::2001
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|142.250.190.97|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5705280 (5.4M) [application/octet-stream]
# Saving to: ‘shell.fits.fz’
#
# shell.fits.fz       100%[===================>]   5.44M  1.68MB/s    in 3.2s
#
# utime(shell.fits.fz): Operation not permitted
# 2024-08-29 14:44:24 (1.68 MB/s) - ‘shell.fits.fz’ saved [5705280/5705280]
#
# --2024-08-29 14:44:24--  https://drive.google.com/uc?export=download&id=1JhtFwOzfHG5YWXUDYP1HFfAkq6v5YHKm
# Resolving drive.google.com (drive.google.com)... 142.250.190.78, 2607:f8b0:4009:80a::200e
# Connecting to drive.google.com (drive.google.com)|142.250.190.78|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1JhtFwOzfHG5YWXUDYP1HFfAkq6v5YHKm&export=download [following]
# --2024-08-29 14:44:25--  https://drive.usercontent.google.com/download?id=1JhtFwOzfHG5YWXUDYP1HFfAkq6v5YHKm&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 142.250.191.129, 2607:f8b0:4009:818::2001
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|142.250.191.129|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 370432 (362K) [application/octet-stream]
# Saving to: ‘halos.npy’
#
# halos.npy           100%[===================>] 361.75K  1.67MB/s    in 0.2s
#
# utime(halos.npy): Operation not permitted
# 2024-08-29 14:44:27 (1.67 MB/s) - ‘halos.npy’ saved [370432/370432]

# %% [markdown]
# ## Load shell and catalog

# %%
min_z = 0.2129219
max_z = 0.2395602

halos = np.load('halos.npy')


#Compute thickness of the shell for projection scale
shell_thickness = ccl.comoving_radial_distance(cosmo, 1/(max_z + 1)) - ccl.comoving_radial_distance(cosmo, 1/(min_z + 1))
bpar['proj_cutoff'] = shell_thickness/2

print(f"SHELL IS {shell_thickness} MPC")


#This is set in units of halo R200c radius.
#You want this to be larger than the radius where you displacement
#function asymptotes to 0
bpar['epsilon_max'] = 10
# Out:
# SHELL IS 103.99377965173323 MPC

# %% [markdown]
# ## Now setup the models

# %%
#Generate a series of 5 models, varying a parameter (M_c)

M_c_vals = [1e12, 1e13, 1e14, 1e15, 1e16]
Model    = []
for M_c in M_c_vals:
    
    bpar['M_c'] = M_c
    
    #Get the pressure profile
    Gas = bfn.Profiles.Gas(**bpar)
    DMB = bfn.Profiles.DarkMatterBaryon(**bpar)
    PRS = bfn.Profiles.Pressure(gas = Gas, darkmatterbaryon = DMB)
    PRS = bfn.Profiles.ThermalSZ(PRS) #Converts Pressure from cgs to compton-y (dimensionless) units
    
    #Now add the HealPix pixel (a redshift-dependent kernel)
    Pix = bfn.utils.HealPixel(NSIDE = 1024)
    PRS = bfn.utils.ConvolvedProfile(PRS, Pix)
    
    
    #Now tabulate it (this does both 3D and 2D tabulation)
    PRS = bfn.utils.TabulatedProfile(PRS, cosmo)
    PRS.setup_interpolator(z_min = min_z, z_max = max_z, N_samples_z = 2, z_linear_sampling = True, 
                           R_min = 1e-4, R_max = 300, N_samples_R = 2000, verbose = True)
    
    Model.append(PRS)
# Out:
# Building Table: 100%|█████████████████████████████████████████████████████████████████████| 2/2 [00:11<00:00,  5.89s/it]
# ../../Baryonification/utils/Tabulate.py:69: RuntimeWarning: divide by zero encountered in log
#   self.interp3D = interpolate.RegularGridInterpolator(input_grid_1, np.log(interp3D), bounds_error = False)
# ../../Baryonification/utils/Tabulate.py:70: RuntimeWarning: invalid value encountered in log
#   self.interp2D = interpolate.RegularGridInterpolator(input_grid_1, np.log(interp2D), bounds_error = False)
# Building Table: 100%|█████████████████████████████████████████████████████████████████████| 2/2 [00:08<00:00,  4.48s/it]
# Building Table: 100%|█████████████████████████████████████████████████████████████████████| 2/2 [00:09<00:00,  4.52s/it]
# Building Table: 100%|█████████████████████████████████████████████████████████████████████| 2/2 [00:09<00:00,  4.53s/it]
# Building Table: 100%|█████████████████████████████████████████████████████████████████████| 2/2 [00:09<00:00,  4.52s/it]

# %% [markdown]
# ## Now setup the runners

# %%
#Each model gets its own runner
cdict   = {'Omega_m' : 0.3175, 'sigma8' : 0.834, 'h' : 0.6711, 'n_s' : 0.9649, 'w0' : -1, 'Omega_b' : 0.049}
halos   = bfn.utils.HaloLightConeCatalog(halos['ra'], halos['dec'], halos['M'], halos['z'], cosmo = cdict)

#Just need an empty shell to paint into, so feed it an empty map at the NSIDE you want
shell   = bfn.utils.LightconeShell(np.zeros(hp.nside2npix(1024)), cosmo = cdict)
Runners = []

for M in Model:
    
    Runners.append(
        bfn.Runners.PaintProfilesShell(halos, shell, epsilon_max = bpar['epsilon_max'], model = M, verbose = True)
    )

# %% [markdown]
# ## Now run it!

# %%
#You can run it in serial

painted_shell = Runners[0].process()
# Out:
# Painting Profile: 100%|██████████████████████████████████████████████████████████| 18512/18512 [00:36<00:00, 511.44it/s]

# %%
#You can also run individual models in parallel,
#since we can paint over individual halos and accumulate
#at the end. So we split halos into batches, and each process
#works with just one of the batches. The maps are summed in the end
#to get contributions from all halos.

#I set it to 1 here though since my laptop struggles with parallel computing :P
Parallel_Runner = bfn.utils.SplitJoinParallel(Runners[0], njobs = 1)
painted_shell   = Parallel_Runner.process()
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   36.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   36.1s finished

# %%
# You can run across the 5 models in parallel as well! :)
# I set njobs to 1 just to have this run on my (aging :P) laptop

Parallel_Runner = bfn.utils.SimpleParallel(Runners, njobs = 1)
painted_shells  = Parallel_Runner.process()
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Painting Profile: 100%|██████████████████████████████████████████████████████████| 18512/18512 [00:37<00:00, 498.91it/s]
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   39.0s remaining:    0.0s
# Painting Profile: 100%|██████████████████████████████████████████████████████████| 18512/18512 [00:36<00:00, 502.74it/s]
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:  1.3min remaining:    0.0s
# Painting Profile: 100%|██████████████████████████████████████████████████████████| 18512/18512 [00:38<00:00, 475.23it/s]
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:  2.0min remaining:    0.0s
# Painting Profile: 100%|██████████████████████████████████████████████████████████| 18512/18512 [00:38<00:00, 478.93it/s]
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:  2.7min remaining:    0.0s
# Painting Profile: 100%|██████████████████████████████████████████████████████████| 18512/18512 [00:37<00:00, 488.26it/s]
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:  3.3min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:  3.3min finished

# %% [markdown]
# ## Plot the Cls

# %%
for s, M in zip(painted_shells, M_c_vals):
    
    #Compute Cls of the modified map
    modified = hp.anafast(s)
    ell      = np.arange(modified.size)
    
    #Plot Cls. Dont show monopole and dipole modes
    plt.plot(ell[2:], (ell * (ell + 1) * modified)[2:], label = f'log10(Mc) = {int(np.log10(M))}')
    

plt.legend(frameon = False)
plt.xlabel('ell', size = 25)
plt.ylabel('compton-y [ell * (ell + 1)]', size = 25)
plt.xscale('log'); plt.yscale('log');
