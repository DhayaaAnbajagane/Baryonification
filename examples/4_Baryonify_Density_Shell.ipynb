# %%
import matplotlib.pyplot as plt
import numpy as np
import healpy as hp
import sys, os; sys.path.append('../../')
import Baryonification as bfn
import pyccl as ccl
from astropy.io import fits

#Load cosmology object from CCL. Linear P(k) is needed since we use it for 2-halo term.
#We don't use P(k) anywhere else in this model, so it's ok to use linear P(k) throughout
cosmo = ccl.Cosmology(Omega_c = 0.3175, Omega_b = 0.049, h = 0.6711, sigma8 = 0.834, n_s = 0.9649, 
                      matter_power_spectrum='linear')

#Config params. Can change as you need. I store these as a dict and then unpack.
bpar = np.load('./default_config.npy', allow_pickle = True)[()]

#Just to make the variation in params more extreme
bpar['mu_beta'] = 1

# %%
#Some plotting configs
plt.rc('text', usetex=True)
plt.rc('font', family='serif', size=22)
plt.rcParams["axes.linewidth"]  = 2.0
plt.rcParams["xtick.major.size"]  = 10
plt.rcParams["xtick.minor.size"]  = 5
plt.rcParams["ytick.major.size"]  = 10
plt.rcParams["ytick.minor.size"]  = 5
plt.rcParams["xtick.direction"]  = "in"
plt.rcParams["ytick.direction"]  = "in"
plt.rcParams["legend.frameon"] = 'False'
plt.rcParams['figure.figsize'] = [10, 10]

# %% [markdown]
# ## Download files
#
# These are files from the [ULAGAM simulations](https://ulagam-simulations.readthedocs.io/) hosted on gdrive specifically for this example notebook

# %%
# !rm shell.fits.fz halos.npy

# !wget -O shell.fits.fz "https://drive.google.com/uc?export=download&id=1JjH5EnW4TlNF8n823K9-DnbkqczL5dj6"
# !wget -O halos.npy     "https://drive.google.com/uc?export=download&id=1JhtFwOzfHG5YWXUDYP1HFfAkq6v5YHKm"
# Out:
# --2024-08-30 16:13:02--  https://drive.google.com/uc?export=download&id=1JjH5EnW4TlNF8n823K9-DnbkqczL5dj6
# Resolving drive.google.com (drive.google.com)... 142.250.190.110, 2607:f8b0:4009:80b::200e
# Connecting to drive.google.com (drive.google.com)|142.250.190.110|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1JjH5EnW4TlNF8n823K9-DnbkqczL5dj6&export=download [following]
# --2024-08-30 16:13:02--  https://drive.usercontent.google.com/download?id=1JjH5EnW4TlNF8n823K9-DnbkqczL5dj6&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 172.217.1.97, 2607:f8b0:4009:801::2001
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|172.217.1.97|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5705280 (5.4M) [application/octet-stream]
# Saving to: ‘shell.fits.fz’
#
# shell.fits.fz       100%[===================>]   5.44M  3.71MB/s    in 1.5s
#
# utime(shell.fits.fz): Operation not permitted
# 2024-08-30 16:13:05 (3.71 MB/s) - ‘shell.fits.fz’ saved [5705280/5705280]
#
# --2024-08-30 16:13:06--  https://drive.google.com/uc?export=download&id=1JhtFwOzfHG5YWXUDYP1HFfAkq6v5YHKm
# Resolving drive.google.com (drive.google.com)... 142.250.191.110, 2607:f8b0:4009:817::200e
# Connecting to drive.google.com (drive.google.com)|142.250.191.110|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1JhtFwOzfHG5YWXUDYP1HFfAkq6v5YHKm&export=download [following]
# --2024-08-30 16:13:06--  https://drive.usercontent.google.com/download?id=1JhtFwOzfHG5YWXUDYP1HFfAkq6v5YHKm&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 142.250.191.193, 2607:f8b0:4009:81a::2001
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|142.250.191.193|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 370432 (362K) [application/octet-stream]
# Saving to: ‘halos.npy’
#
# halos.npy           100%[===================>] 361.75K  1.43MB/s    in 0.2s
#
# utime(halos.npy): Operation not permitted
# 2024-08-30 16:13:08 (1.43 MB/s) - ‘halos.npy’ saved [370432/370432]

# %% [markdown]
# ## Load shell and catalog

# %%
min_z = 0.2129219
max_z = 0.2395602

# %%
counts  = fits.open('shell.fits.fz')[1].data
density = counts/np.mean(counts) - 1

hp.mollview(np.log10(1.1 + density))
# Out:
# /home/dhaya/miniconda3/envs/pyccl_env_extended/lib/python3.9/site-packages/healpy/projaxes.py:920: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. This has been deprecated since 3.3 and in 3.6, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = mpl.cm.get_cmap("viridis").copy()
#   newcm.set_over(newcm(1.0))
# /home/dhaya/miniconda3/envs/pyccl_env_extended/lib/python3.9/site-packages/healpy/projaxes.py:921: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. This has been deprecated since 3.3 and in 3.6, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = mpl.cm.get_cmap("viridis").copy()
#   newcm.set_under(bgcolor)
# /home/dhaya/miniconda3/envs/pyccl_env_extended/lib/python3.9/site-packages/healpy/projaxes.py:922: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. This has been deprecated since 3.3 and in 3.6, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = mpl.cm.get_cmap("viridis").copy()
#   newcm.set_bad(badcolor)
# /home/dhaya/miniconda3/envs/pyccl_env_extended/lib/python3.9/site-packages/healpy/projaxes.py:202: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   aximg = self.imshow(

# %%
halos = np.load('halos.npy')

# %%
shell_thickness = ccl.comoving_radial_distance(cosmo, 1/(max_z + 1)) - ccl.comoving_radial_distance(cosmo, 1/(min_z + 1))
bpar['proj_cutoff'] = shell_thickness/2

print(f"SHELL IS {shell_thickness} MPC")
# Out:
# SHELL IS 103.99377965173323 MPC

# %%
#This is set in units of halo R200c radius.
#You want this to be larger than the radius where you displacement
#function asymptotes to 0
bpar['epsilon_max'] = 10

# %% [markdown]
# ## Now setup the models

# %%
#Generate a series of 5 models, varying a parameter (M_c)

M_c_vals = [1e12, 1e13, 1e14, 1e15, 1e16]
Model    = []
for M_c in M_c_vals:
    
    bpar['M_c'] = M_c
    
    #DMO and DMB models
    DMO = bfn.Profiles.DarkMatterOnly(**bpar)
    DMB = bfn.Profiles.DarkMatterBaryon(**bpar)

    #Regular displacement model. We init it and also run the tabulator
    Displacement = bfn.Profiles.Baryonification3D(DMO, DMB, cosmo = cosmo, epsilon_max = bpar['epsilon_max'])
    Displacement.setup_interpolator(z_min = min_z, z_max = max_z, N_samples_z = 2, z_linear_sampling = True, 
                                    R_min = 1e-4, R_max = 300, N_samples_R = 2000, verbose = True)
    
    Model.append(Displacement)
# Out:
# Building Table: 100%|█████████████████████████████████████████████████████████████████████| 2/2 [00:10<00:00,  5.02s/it]
# Building Table: 100%|█████████████████████████████████████████████████████████████████████| 2/2 [00:05<00:00,  2.91s/it]
# Building Table: 100%|█████████████████████████████████████████████████████████████████████| 2/2 [00:05<00:00,  2.94s/it]
# Building Table: 100%|█████████████████████████████████████████████████████████████████████| 2/2 [00:06<00:00,  3.05s/it]
# Building Table: 100%|█████████████████████████████████████████████████████████████████████| 2/2 [00:06<00:00,  3.22s/it]

# %% [markdown]
# ## Now setup the runners

# %%
#Each model gets its own runner

#A dictionary of cosmology params to pass to runner
cdict   = {'Omega_m' : 0.3175, 'sigma8' : 0.834, 'h' : 0.6711, 'n_s' : 0.9649, 'w0' : -1, 'Omega_b' : 0.049}

#Put halos and the field into I/O objects.
#The shell should be a MASS shell, not a density shell.
halos   = bfn.utils.HaloLightConeCatalog(halos['ra'], halos['dec'], halos['M'], halos['z'], cosmo = cdict)
shell   = bfn.utils.LightconeShell(map = counts, cosmo = cdict)
Runners = []

for M in Model:
    
    Runners.append(
        bfn.Runners.BaryonifyShell(halos, shell, epsilon_max = bpar['epsilon_max'], model = M, verbose = True)
    )

# %% [markdown]
# ## Now run it!

# %%
#You can run each runner one-by-one, in serial
#Note that the tqdm progress only shows accumulating the displacements
#There is a somewhat long, "application" step that does the re-assignment
#of mass back to the grid.

baryonified_shell = Runners[0].process()
# Out:
# Baryonifying matter: 100%|███████████████████████████████████████████████████████| 18512/18512 [00:41<00:00, 443.65it/s]

# %%
# Or even better, you can run it in parallel! :)
# I set njobs to 1 just to have this run on my (aging :P) laptop

Parallel_Runner    = bfn.utils.SimpleParallel(Runners, njobs = 1)
baryonified_shells = Parallel_Runner.process()
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Baryonifying matter: 100%|███████████████████████████████████████████████████████| 18512/18512 [00:41<00:00, 445.16it/s]
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   58.4s remaining:    0.0s
# Baryonifying matter: 100%|███████████████████████████████████████████████████████| 18512/18512 [00:40<00:00, 452.86it/s]
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:  1.9min remaining:    0.0s
# Baryonifying matter: 100%|███████████████████████████████████████████████████████| 18512/18512 [00:40<00:00, 457.69it/s]
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:  3.2min remaining:    0.0s
# Baryonifying matter: 100%|███████████████████████████████████████████████████████| 18512/18512 [00:42<00:00, 438.84it/s]
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:  4.1min remaining:    0.0s
# Baryonifying matter: 100%|███████████████████████████████████████████████████████| 18512/18512 [00:41<00:00, 449.73it/s]
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:  5.1min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:  5.1min finished

# %% [markdown]
# ## Finally, let's plot the ratios of Cls

# %%
#Compute Cls of the original map
baseline = hp.anafast(counts)
ell      = np.arange(baseline.size)

for s, M in zip(baryonified_shells, M_c_vals):
    
    #Compute Cls of the modified map
    modified = hp.anafast(s)
    
    #Plot ratios. Dont show monopole and dipole modes
    plt.plot(ell[2:], (modified/baseline)[2:], label = f'log10(Mc) = {int(np.log10(M))}')
    

plt.legend(frameon = False)
plt.xlabel('ell', size = 25)
plt.ylabel('Ratio', size = 25)
plt.xscale('log')
